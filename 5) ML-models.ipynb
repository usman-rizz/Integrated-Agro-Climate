# %% [markdown]
# <h1 style="text-align:center;
#            background:#d9ecf2;
#            color:#045174;
#            font-size:45px;
#            padding:20px;
#            border-radius:12px;">
#      <b> 🌧️ Rainfall & Climate Modling</b>
# </h1>

# %% [markdown]
# <h2 style="text-align:center;
#            background:#d9ecf2;
#            color:#045174;
#            font-size:45px;
#            padding:15px;
#            border-radius:12px;
#            display: inline-block">
#      <b> Importing Libraries</b>
# </h2>

# %% [markdown]
# <h2 style="
#            background:#d9ecf2;
#            color:#045174;
#            font-size:45px;
#            padding:15px;
#            border-radius:12px;
#            display: inline-block;">
#      <b>Data Loading | Models Implementation</b>
# </h2>

# %%
data = pd.read_csv("4) cleaned_weather_data.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_csv("4) cleaned_weather_data.csv")
#       2 data.head()
#
# NameError: name 'pd' is not defined
